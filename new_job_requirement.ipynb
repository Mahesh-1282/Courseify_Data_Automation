# %%
hey eppudu manam code lo pedda modifications cheyyali sarey naa adhi enti antey nenu data format antha marchi update chesanu so nuvvu em cheyyali antey


edhigo data for py_eng.json

{
    "id": "py_eng",
    "title": "Python English",
    "description": "Python Basics to Advance Full Course",
    "shared_notes_id": "py_notes_shared",
    "disclaimer": "This course aggregates highly-rated YouTube tutorials to provide a structured learning path. All video content is hosted on YouTube, ensuring that creators receive full credit, engagement, and views for their valuable contributions.",
    "chapters": [
        {
            "id": 0,
            "title": "Introduction & Setup",
            "videos": [
                {
                    "video_title": "Introduction to Python Course",
                    "video_link": "6i3EGqOBRiU",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Introduction to Python Programming",
                    "video_link": "DInMru2Eq6E",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "History of Python",
                    "video_link": "1UzSDMJRh8c",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Download and Install Python & Pycharm",
                    "video_link": "La1BdF_sunw",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Python Indentation",
                    "video_link": "xVndqyPFu-k",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 1,
            "title": "Variables & Data Types",
            "videos": [
                {
                    "video_title": "Variables in Python",
                    "video_link": "a43BIxiZ5EM",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise: Swap Two Numbers",
                    "video_link": "A8aYYz6YGCA",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Variable Naming Rules",
                    "video_link": "Vn4RuZ4Y2M0",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Data Types in Python",
                    "video_link": "TTepNRy0wj8",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 2,
            "title": "Type Casting",
            "videos": [
                {
                    "video_title": "Type Checking & Type Conversion (Casting)",
                    "video_link": "_WY-p2ZKv9Q",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise: Add Digits of a Number",
                    "video_link": "b7QWOgVjj1M",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 3,
            "title": "Basic I/O",
            "videos": [
                {
                    "video_title": "Writing First Python Program (Print to Console)",
                    "video_link": "lygaoUnJKF4",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #1 (Basic I/O)",
                    "video_link": "FP6qQgJI5f4",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "print() function & String Concatenation",
                    "video_link": "6Nu9cvINQLk",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Input function (Take User Input)",
                    "video_link": "sa97IyIOHxU",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "f-Strings in Python",
                    "video_link": "xGkF9Y38Gsc",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #5 (Basic I/O)",
                    "video_link": "O2V97JC8zOY",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 4,
            "title": "Operators",
            "videos": [
                {
                    "video_title": "Arithmetic Operators",
                    "video_link": "kvVPeBBZdtM",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Assignment and Comparison Operators",
                    "video_link": "ELNIUknegOE",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Logical Operators",
                    "video_link": "-Mx5popgTtE",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Bitwise Operators",
                    "video_link": "XbjQ-heGd58",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Identity Operators",
                    "video_link": "BG3lg589HRE",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Membership Operators",
                    "video_link": "MHl0Jj15crA",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #4 (Operators)",
                    "video_link": "0kLylf5uNNc",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 5,
            "title": "Conditional Statements",
            "videos": [
                {
                    "video_title": "If & If Else Statements",
                    "video_link": "MMzXz7EDTZM",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #6 (Conditional Statements)",
                    "video_link": "WOvtTLePD3M",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Nested If Else & elif Statements",
                    "video_link": "7498T9qPygI",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #7 (Conditional Statements)",
                    "video_link": "a3n_9k06dY8",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #8 (Conditional Statements)",
                    "video_link": "sY6j_UR3pGI",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Multiple if Statements",
                    "video_link": "O3MA3Hn7c2E",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #9 (Conditional Statements)",
                    "video_link": "9OwSWGguQXs",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Love Calculator",
                    "video_link": "iRF5AB1VRS8",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 6,
            "title": "Loops & Loop Control",
            "videos": [
                {
                    "video_title": "For Loop in Python",
                    "video_link": "k4R7FwL2XYA",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "For else in Python",
                    "video_link": "jDJ718e-YIw",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Exercise 14 (For Loop)",
                    "video_link": "u-Ptydkqh7E",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Exercise 15 (For Loop)",
                    "video_link": "rzMdf7cmHc0",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Range function in Python",
                    "video_link": "YNDgutH6gjs",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Exercise 16 (Loops)",
                    "video_link": "sI_Wb3JPQg8",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Exercise 17 (Loops)",
                    "video_link": "nxYOmS7p6qY",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Password Generator",
                    "video_link": "hGuA9WKTtRs",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "While Loop in Python",
                    "video_link": "KOfCkEIxh_o",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Break, Continue, Pass (Loop Control)",
                    "video_link": "DpE5TJNNb9Q",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Hangman Game Introduction",
                    "video_link": "dIFRJe2uHB4",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Hangman Game Flowchart",
                    "video_link": "earqUEBeudg",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Hangman Game Complete Code",
                    "video_link": "tMJbCWHAWQ4",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 7,
            "title": "Core Data Structures (Lists, Tuples, Sets, Dictionaries)",
            "videos": [
                {
                    "video_title": "Lists in Python & List Functions",
                    "video_link": "1tnFQDo05hQ",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #12 (Lists)",
                    "video_link": "ORMBycShqnc",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Fix Python Index Error (Lists)",
                    "video_link": "wpmXETzX6xc",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Nested Lists in Python",
                    "video_link": "KEpmUPxxjxI",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #13 (Lists)",
                    "video_link": "jTIODDVCAus",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Rock Paper Scissors Game",
                    "video_link": "Qcefu1jVPds",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Tuples in Python",
                    "video_link": "zLFituJxj6c",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Sets in Python (Part 1)",
                    "video_link": "CTg_To0PwI8",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Sets Methods in Python (Part 2)",
                    "video_link": "eEbTvbG3los",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Sets Methods in Python (Part 3)",
                    "video_link": "bniKXiB72lU",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Sets Methods in Python (Part 4)",
                    "video_link": "k1-ZjeIDnPo",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Dictionaries in Python & Built-in Functions",
                    "video_link": "C29qMZb9HrA",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #23 (Dictionaries)",
                    "video_link": "l-2HkbQymmM",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Nested Dictionaries in Python",
                    "video_link": "jakXbai-Wic",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #24 (Dictionaries)",
                    "video_link": "O1-whIFkco0",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Silent Auction Program (Part 1)",
                    "video_link": "O_48EL9Zg0E",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Silent Auction Program (Complete Code)",
                    "video_link": "oS8FekoPFKM",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 8,
            "title": "Comprehensions",
            "videos": [
                {
                    "video_title": "Comprehensions",
                    "video_link": "3dt4OGnU5sM",
                    "channel": "coreyms"
                }
            ]
        },
        {
            "id": 9,
            "title": "Functions Basics & Arguments",
            "videos": [
                {
                    "video_title": "Functions in Python Introduction",
                    "video_link": "eezLhJ5oGYg",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #18 (Functions)",
                    "video_link": "-gxUjXAG96U",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #19 (Functions)",
                    "video_link": "O79JMm7GFlA",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #20 (Functions)",
                    "video_link": "JpBamlGdb5I",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Functions with Arguments (Parameters vs Arguments)",
                    "video_link": "uY8QPE0dcSs",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Types of Arguments in Python",
                    "video_link": "OCbSteqZsKQ",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "*args and **kwargs in Python",
                    "video_link": "pY6mZ-RbBZg",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #21 (Functions)",
                    "video_link": "vvroag3Qds8",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #22 (Functions)",
                    "video_link": "P2l6tzvHQWo",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Caesar Cipher Introduction",
                    "video_link": "0heejX0rtII",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Caesar Cipher Complete Code",
                    "video_link": "HWhUuO7VV1o",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Functions with Return Statement",
                    "video_link": "LF7gVwJP8BA",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Return Multiple Values from a Function",
                    "video_link": "-tb0Ur5_pjU",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #25 (Functions)",
                    "video_link": "_LMhfUIWfiU",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "print vs return in Python",
                    "video_link": "19PXDJCU3oc",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Calculator",
                    "video_link": "vlJ--mCPBCg",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 10,
            "title": "Scope (Local vs Global)",
            "videos": [
                {
                    "video_title": "Local and Global Scope",
                    "video_link": "3iIq6gq_xRo",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Global keyword (Modify Global Variable)",
                    "video_link": "4mmqLhTxTVk",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Guess The Number Game",
                    "video_link": "QXX2ySfwEBM",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Higher Lower Game",
                    "video_link": "BbBUns9yDEM",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Coffee Machine",
                    "video_link": "oREXmJPvLWk",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 11,
            "title": "Lambda Functions",
            "videos": [
                {
                    "video_title": "Lambda Functions",
                    "video_link": "IljPHDyBRog",
                    "channel": "BroCodez"
                }
            ]
        },
        {
            "id": 12,
            "title": "Built-in Functions",
            "videos": [
                {
                    "video_title": "round() function in Python",
                    "video_link": "CLjw2nCMpSY",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "range() function in Python",
                    "video_link": "YNDgutH6gjs",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 13,
            "title": "Modules & Packages",
            "videos": [
                {
                    "video_title": "Random Module in Python",
                    "video_link": "khZKoe0_B0I",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise: Heads or Tails (using Random Module)",
                    "video_link": "7niNK-917fI",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Modules in Python",
                    "video_link": "L6BoHn8NdX4",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "pip & PyPI (Packages in Python)",
                    "video_link": "h2fu66y0_uA",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Packages in Python",
                    "video_link": "bcDMDlH3Vu8",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "If __name__ == '__main__' in Python",
                    "video_link": "8qlf6Cg037o",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Extracting RGB values (Colorgram Package)",
                    "video_link": "q06z4k57R5E",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 14,
            "title": "Classes & Objects",
            "videos": [
                {
                    "video_title": "Introduction to OOP",
                    "video_link": "Ic7ZBKqkS1E",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Classes and Objects",
                    "video_link": "Gvm2Sg1rZek",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 15,
            "title": "Attributes & Methods",
            "videos": [
                {
                    "video_title": "self and __init__() method",
                    "video_link": "G6Bd6tJ9ft0",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Class Methods",
                    "video_link": "tJNsmm7ZUmk",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #26 (Classes & Methods)",
                    "video_link": "cezNT43xmAY",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 16,
            "title": "Inheritance & Polymorphism",
            "videos": [
                {
                    "video_title": "Inheritance in Python",
                    "video_link": "4SO3sScshvA",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Multiple Inheritance",
                    "video_link": "Smlbgao6VL4",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Multilevel Inheritance",
                    "video_link": "Fv1xFd3LzJo",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Hierarchical Inheritance",
                    "video_link": "UYxJBJQZU-I",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Hybrid Inheritance",
                    "video_link": "E6aDQWX-ASc",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Diamond Problem & MRO",
                    "video_link": "PSMYqfMP3Cs",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Polymorphism in Python",
                    "video_link": "UPT4Q_sTOpY",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Duck Typing in Python",
                    "video_link": "mbpHqb04BI8",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Operator Overloading (Polymorphism)",
                    "video_link": "CGZJ-d4T5eQ",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Method Overloading and Overriding",
                    "video_link": "1gJQMSZ05HA",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 17,
            "title": "Encapsulation & Abstraction",
            "videos": [
                {
                    "video_title": "Abstraction in Python",
                    "video_link": "TenfEct8AxM",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Abstract Class & Method",
                    "video_link": "64tJdFVh1Vs",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Access Modifiers (Public, Protected, Private)",
                    "video_link": "aF6usfcTYqQ",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Encapsulation & Getters/Setters",
                    "video_link": "fjIUS1jlVkA",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 18,
            "title": "Magic/Dunder Methods",
            "videos": [
                {
                    "video_title": "Magic/Dunder Methods in Python",
                    "video_link": "ZZ04bIag-HU",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Coding Exercise #27 (Dunder Methods)",
                    "video_link": "F7cm393pMYk",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 19,
            "title": "File Handling",
            "videos": [
                {
                    "video_title": "File Handling in Python",
                    "video_link": "Sx1Hjr67xO0",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Quiz Game",
                    "video_link": "YhmF0NQO0LQ",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        },
        {
            "id": 20,
            "title": "Exception Handling",
            "videos": [
                {
                    "video_title": "Exception Handling",
                    "video_link": "NIWwJbo-9_8",
                    "channel": "coreyms"
                }
            ]
        },
        {
            "id": 21,
            "title": "Iterators & Generators",
            "videos": [
                {
                    "video_title": "Iterators & Generators",
                    "video_link": "jTYiNjvnHZY",
                    "channel": "coreyms"
                }
            ]
        },
        {
            "id": 22,
            "title": "Decorators",
            "videos": [
                {
                    "video_title": "Decorators",
                    "video_link": "FsAPt_9Bf3U",
                    "channel": "coreyms"
                }
            ]
        },
        {
            "id": 23,
            "title": "Regular Expressions (Regex)",
            "videos": [
                {
                    "video_title": "Regular Expressions (Regex)",
                    "video_link": "K8L6KVGG-7o",
                    "channel": "coreyms"
                }
            ]
        },
        {
            "id": 24,
            "title": "Advanced Concepts Overview",
            "videos": [
                {
                    "video_title": "Debugging in Python",
                    "video_link": "wxvYoQBCap4",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Higher Lower Game",
                    "video_link": "BbBUns9yDEM",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Project: Coffee Machine",
                    "video_link": "oREXmJPvLWk",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Exercise 30 (Advanced Concepts)",
                    "video_link": "FFrBaOUgbgg",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Exercise 31 (Advanced Concepts)",
                    "video_link": "HiTbawXkcIA",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Exercise 32 (Advanced Concepts)",
                    "video_link": "i0cbG0hlWg8",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Python Higher Order Functions",
                    "video_link": "KKJ-Vvewu0w",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Python Event Listeners",
                    "video_link": "7dnk_wE79i4",
                    "channel": "JennyslecturesCSIT"
                },
                {
                    "video_title": "Exercise 33 (Advanced Concepts)",
                    "video_link": "sql6iaFe5D4",
                    "channel": "JennyslecturesCSIT"
                }
            ]
        }
    ]
}

denni nenu enc lo istanu sarey naa so baga think chesi exact output ivvava pls.

and also notes ni koda update chesanu so nuvvu mottam read aa course_id/topic_id ni base chesukoni from 0-24 ani undhi kada so each topic ki okatey notes and single page questions matramey unnaye sarey na so nuvvu baga think chesi exact ga aa test notes ni koda ela add cheyyalo chesi ivvu sarey naa

and notes koda chupistanu chudu

{
    "course_notes": {
        "py_notes_shared": {
            "0": {
                "notes": "# \ud83d\ude80 Python: Introduction & Setup\n\n## \ud83c\udfaf Overview & Real-world Analogy\nImagine Python as a super-smart, friendly robot assistant \ud83e\udd16 that understands human-like instructions. Instead of complex machine code, you give it commands in a language that's easy to read and write. This robot can do almost anything: build websites, analyze huge amounts of data, create games, or even control other robots! It's like a universal translator and a Swiss Army knife all rolled into one, making complex tasks simple and accessible.\n\n## \ud83d\udccc Core Concepts\n\n### 1. What is Python? \ud83e\udd14\nPython is a high-level, interpreted, general-purpose programming language. This means:\n*   **High-level:** You write code closer to human language, not machine code.\n*   **Interpreted:** Your code is executed line by line by an 'interpreter' program, without needing a separate compilation step first.\n*   **General-purpose:** It's not specialized for one task; you can use it for almost anything!\n\n**Example:**\n```python\n# A simple Python command\nprint(\"Hello, Python World!\")\n```\n\n### 2. Why Python? \ud83c\udf1f\nPython's popularity stems from several key advantages:\n*   **Readability:** Its syntax is clean and easy to understand, making it great for beginners and collaborative projects.\n*   **Versatility:** Used in web development (Django, Flask), data science (Pandas, NumPy), artificial intelligence (TensorFlow, PyTorch), automation, game development, and more.\n*   **Large Community & Libraries:** A massive ecosystem of pre-built modules and a supportive community mean you rarely have to start from scratch.\n\n**Example (showing versatility concept - no direct code for 'why', but a hint):**\n```python\n# Web development snippet (Flask framework)\nfrom flask import Flask\napp = Flask(__name__)\n\n@app.route('/')\ndef hello():\n    return \"Hello from a Python web app!\"\n\n# Data analysis snippet (Pandas library)\nimport pandas as pd\ndata = {'Name': ['Alice', 'Bob'], 'Age': [30, 24]}\ndf = pd.DataFrame(data)\nprint(df)\n```\n\n### 3. Setting Up Your Python Environment \ud83d\udee0\ufe0f\nBefore you can code, you need a place to write and run your Python programs.\n\n#### a. Python Interpreter Installation\nThis is the core program that understands and executes your Python code. You download it from python.org. Most operating systems (Linux, macOS) come with Python pre-installed, but it's often an older version. It's best to install the latest stable version yourself.\n\n**Example (Checking your Python version in a terminal/command prompt):**\n```bash\npython --version\n# or sometimes\npython3 --version\n```\n\n#### b. Code Editors & IDEs (Integrated Development Environments)\nThese are tools where you write your code. They offer features like syntax highlighting, auto-completion, and debugging.\n*   **VS Code (Visual Studio Code):** Popular, lightweight, and highly customizable with extensions.\n*   **PyCharm:** A powerful IDE specifically designed for Python, great for larger projects.\n*   **Jupyter Notebooks:** Excellent for data science and interactive computing, allowing you to mix code, text, and visualizations.\n\n**Example (A simple Python file `hello.py` opened in an editor):**\n```python\n# hello.py\nmessage = \"Welcome to Python!\"\nprint(message)\n```\n\n**Example (Running the `hello.py` script from the terminal):**\n```bash\npython hello.py\n```\n\n#### c. Virtual Environments (venv) \ud83c\udf33\nThis is a crucial concept! A virtual environment creates an isolated space for your Python projects. Imagine each project having its own dedicated toolbox with specific versions of libraries, preventing conflicts between different projects.\n\n**Example (Creating and activating a virtual environment):**\n```bash\n# 1. Navigate to your project folder\ncd my_python_project\n\n# 2. Create a virtual environment named 'venv'\npython -m venv venv\n\n# 3. Activate the virtual environment\n# On macOS/Linux:\nsource venv/bin/activate\n\n# On Windows (Command Prompt):\nvirtual_env_name\\Scripts\\activate.bat\n\n# On Windows (PowerShell):\nvirtual_env_name\\Scripts\\Activate.ps1\n\n# You'll see '(venv)' or similar in your prompt, indicating it's active.\n\n# 4. Install a package (e.g., requests) into THIS environment\npip install requests\n\n# 5. Deactivate when done\ndeactivate\n```\n\n### 4. Basic Python Syntax: Your First Steps \u270d\ufe0f\n\n#### a. The `print()` Function\nUsed to display output to the console.\n\n**Example:**\n```python\nprint(\"Hello, world!\")\nprint(123)\nprint(\"My name is\", \"Alice\")\n```\n\n#### b. Variables\nUsed to store data. Python is dynamically typed, meaning you don't declare the variable's type explicitly.\n\n**Example:**\n```python\nname = \"Bob\"       # Stores text (string)\nage = 25           # Stores a whole number (integer)\nheight = 1.75      # Stores a decimal number (float)\nis_student = True  # Stores a boolean (True/False)\n\nprint(name)\nprint(age)\n```\n\n#### c. Comments\nLines of code ignored by the interpreter, used to explain your code.\n\n**Example:**\n```python\n# This is a single-line comment\nprint(\"This line runs.\") # You can also comment at the end of a line\n\n\"\"\"\nThis is a multi-line comment (or docstring if at the start of a function/class).\nIt spans multiple lines and is useful for longer explanations.\n\"\"\"\nprint(\"Another line of code.\")\n```\n\n## \ud83d\udca1 Pro-Tips & Common Mistakes\n*   **Always use Virtual Environments:** Seriously, make it a habit from day one. It saves countless headaches.\n*   **Indentation is NOT Optional:** Python uses whitespace (spaces/tabs) to define code blocks. Incorrect indentation will lead to `IndentationError`.\n*   **Read Error Messages:** Don't just panic! Python's error messages are often very helpful in pointing out where and why your code broke.\n*   **Start Small:** Don't try to build a complex app immediately. Master the basics with small, focused exercises.\n*   **Practice Regularly:** Consistency is key to becoming proficient.\n\n## \ud83c\udf99\ufe0f Interview Questions\n\n**Q1: What is Python, and what makes it a popular choice for developers?**\n**A1:** Python is a high-level, interpreted, general-purpose programming language. Its popularity comes from its excellent readability (clean syntax), versatility (used in web dev, data science, AI, automation), a vast ecosystem of libraries, and a large, supportive community.\n\n**Q2: Explain the purpose of a virtual environment in Python. Why is it important?**\n**A2:** A virtual environment creates an isolated space for a Python project, allowing it to have its own set of Python packages and dependencies, separate from other projects or the global Python installation. This is crucial because it prevents conflicts between different projects that might require different versions of the same library, ensuring project stability and reproducibility.\n\n**Q3: What's the difference between a code editor and an IDE? Can you name examples of each?**\n**A3:** A **code editor** (like VS Code, Sublime Text) is a lightweight tool primarily for writing and editing code, often with syntax highlighting and basic auto-completion. An **IDE (Integrated Development Environment)** (like PyCharm, Eclipse) is a more comprehensive software suite that includes a code editor, but also integrates many other development tools such as a debugger, compiler/interpreter, build automation tools, and version control integration, offering a richer development experience.\n",
                "practice_test": [
                    {
                        "q": "Which of the following best describes Python's nature?",
                        "opt": [
                            "Compiled and low-level",
                            "Interpreted and high-level",
                            "Compiled and general-purpose",
                            "Interpreted and low-level"
                        ],
                        "ans_ind": 1,
                        "desc": "Python is an interpreted language, meaning code is executed line by line without a separate compilation step. It is also a high-level language, abstracting away complex machine details for easier human readability."
                    },
                    {
                        "q": "What is the primary purpose of the `print()` function in Python?",
                        "opt": [
                            "To define a new variable",
                            "To perform mathematical calculations",
                            "To display output to the console",
                            "To read input from the user"
                        ],
                        "ans_ind": 2,
                        "desc": "The `print()` function is fundamental for displaying information, messages, or variable values to the standard output (usually the console or terminal)."
                    },
                    {
                        "q": "Why is it recommended to use virtual environments (like `venv`) for Python projects?",
                        "opt": [
                            "To speed up Python code execution",
                            "To make Python code more secure",
                            "To isolate project dependencies and avoid conflicts",
                            "To automatically deploy Python applications"
                        ],
                        "ans_ind": 2,
                        "desc": "Virtual environments create isolated spaces for each project, ensuring that different projects can use different versions of libraries without interfering with each other or the global Python installation. This prevents dependency conflicts."
                    },
                    {
                        "q": "Which of the following is crucial for defining code blocks in Python?",
                        "opt": [
                            "Semicolons at the end of each line",
                            "Curly braces `{}`",
                            "Parentheses `()`",
                            "Consistent indentation"
                        ],
                        "ans_ind": 3,
                        "desc": "Unlike many other languages that use curly braces, Python uses consistent indentation (spaces or tabs) to define code blocks, such as those for loops, functions, or conditional statements. Incorrect indentation will result in an `IndentationError`."
                    },
                    {
                        "q": "How do you typically install a new Python package (e.g., 'requests') into an *active* virtual environment?",
                        "opt": [
                            "python install requests",
                            "pip install requests",
                            "npm install requests",
                            "conda install requests"
                        ],
                        "ans_ind": 1,
                        "desc": "`pip` is the standard package installer for Python. When a virtual environment is active, `pip install <package_name>` installs the package specifically into that environment."
                    },
                    {
                        "q": "What is the correct way to add a single-line comment in Python?",
                        "opt": [
                            "// This is a comment",
                            "/* This is a comment */",
                            "# This is a comment",
                            "-- This is a comment"
                        ],
                        "ans_ind": 2,
                        "desc": "In Python, the hash symbol `#` is used to denote a single-line comment. Any text following `#` on that line is ignored by the interpreter."
                    },
                    {
                        "q": "Which command would you use in the terminal to check the installed Python version?",
                        "opt": [
                            "check python version",
                            "python --version",
                            "get python version",
                            "version python"
                        ],
                        "ans_ind": 1,
                        "desc": "The standard command to check the Python version installed on your system is `python --version` (or `python3 --version` on some systems where `python` might refer to an older version)."
                    }
                ]
            },
            "1": {


endhulo nenu markup notes pettanu so nuvvu eppudu notes ni chupinchadam koda manchi effects tho markdown and also user ki manchi feel tho assala user attention ni grab chesi malli skip avvakunda undeyla manchiga chesi ivvava pls sarey naa

so neku emaina doubts unna adugu nannu nenu courses_index.json lo aa files ni download chesukovali sarey na

so first baga think chesi manchi ui tho for questions, notes ki manchi markdown format lo undeyla chesi ivvava pls sarey naa.

nuvvu present topic_id ki match chesi pettu sarey naa notes data ni sarey na

# %%
import json
import base64
import time
import datetime
from google import genai
from youtube_transcript_api import YouTubeTranscriptApi
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, TimestampType

# Setup
GEMINI_API_KEY = dbutils.secrets.get(scope="courseify", key="gemini-api")
client = genai.Client(api_key=GEMINI_API_KEY)
COURSE_ID = "py_jenny"

# Mana Core 25 Topics Syllabus
SYLLABUS = [
    {"id": 0, "title": "Introduction & Setup"}, {"id": 1, "title": "Variables & Data Types"},
    {"id": 2, "title": "Type Casting"}, {"id": 3, "title": "Basic I/O"},
    {"id": 4, "title": "Operators"}, {"id": 5, "title": "Conditional Statements"},
    {"id": 6, "title": "Loops & Loop Control"}, {"id": 7, "title": "Core Data Structures (Lists, Tuples, Sets, Dictionaries)"},
    {"id": 8, "title": "Comprehensions"}, {"id": 9, "title": "Functions Basics & Arguments"},
    {"id": 10, "title": "Scope (Local vs Global)"}, {"id": 11, "title": "Lambda Functions"},
    {"id": 12, "title": "Built-in Functions"}, {"id": 13, "title": "Modules & Packages"},
    {"id": 14, "title": "Classes & Objects"}, {"id": 15, "title": "Attributes & Methods"},
    {"id": 16, "title": "Inheritance & Polymorphism"}, {"id": 17, "title": "Encapsulation & Abstraction"},
    {"id": 18, "title": "Magic/Dunder Methods"}, {"id": 19, "title": "File Handling"},
    {"id": 20, "title": "Exception Handling"}, {"id": 21, "title": "Iterators & Generators"},
    {"id": 22, "title": "Decorators"}, {"id": 23, "title": "Regular Expressions (Regex)"},
    {"id": 24, "title": "Advanced Concepts Overview"}
]

def get_transcript(video_id):
    try:
        transcript_list = YouTubeTranscriptApi.get_transcript(video_id)
        return " ".join([item['text'] for item in transcript_list])
    except Exception: return ""

def map_videos_to_topics(videos_list):
    print("🧠 AI Mapping videos to 25 main topics...")
    syllabus_str = "\n".join([f"ID {s['id']}: {s['title']}" for s in SYLLABUS])
    videos_str = "\n".join([f"VID {v['video_id']} : {v['video_title']}" for v in videos_list])
    
    prompt = f"""
    Map the following YouTube videos to the most relevant Syllabus Topic. Group similar videos under the same topic_id.
    SYLLABUS TOPICS:
    {syllabus_str}
    
    VIDEOS:
    {videos_str}
    
    Return EXACTLY a JSON array. Format: [{{"video_id": "...", "topic_id": 0, "refined_title": "Clean Name"}}]
    """
    try:
        response = client.models.generate_content(
            model='gemini-2.5-flash', 
            contents=prompt, 
            config={'temperature': 0.1, 'response_mime_type': 'application/json'}
        )
        return json.loads(response.text)
    except Exception as e:
        print(f"Mapping Error: {e}")
        return []

def generate_ai_content(combined_transcript, topic_title):
    prompt = f"""
    You are an Elite Coding Instructor. Generate a Topper-Level study guide and 5-10 multiple-choice questions for the Topic: '{topic_title}'.
    
    OUTPUT FORMAT (EXACTLY VALID JSON):
    {{
        "markdown_notes": "Detailed A-to-Z notes...",
        "practice_test": [
            {{"question": "?", "options": ["A", "B", "C", "D"], "answer_index": 0}}
        ]
    }}
    Source Transcript: {combined_transcript[:25000]}
    """
    try:
        response = client.models.generate_content(
            model='gemini-2.5-flash', 
            contents=prompt, 
            config={'temperature': 0.3, 'response_mime_type': 'application/json'}
        )
        return json.loads(response.text)
    except Exception as e:
        print(f"Content Gen Error: {e}")
        return None

def process_bronze_to_silver():
    # 1. Read Raw Data from Bronze
    bronze_df = spark.sql(f"SELECT video_id, video_title, channel_name FROM courseify.default.course_bronze WHERE course_id = '{COURSE_ID}'")
    videos = [row.asDict() for row in bronze_df.collect()]
    
    if not videos:
        print("No data in Bronze table yet!")
        return

    # 2. Get AI Mapping
    mapping = map_videos_to_topics(videos)
    
    # 3. Group by the 25 Main Topics
    course_structure = {s['id']: {"title": s['title'], "videos": []} for s in SYLLABUS}
    for m in mapping:
        topic_id = m.get('topic_id')
        if topic_id in course_structure:
            course_structure[topic_id]['videos'].append(m)

    silver_data = []
    current_time = datetime.datetime.now()

    # 4. Generate Content for each Main Topic
    for topic_id, data in course_structure.items():
        if not data['videos']: continue # Skip if no videos mapped
            
        print(f"\n⏳ Processing Silver Topic: {data['title']}")
        
        # Check if already processed in Silver table
        existing = spark.sql(f"SELECT 1 FROM courseify.default.course_silver WHERE course_id = '{COURSE_ID}' AND main_topic_id = {topic_id}").count()
        if existing > 0:
            print(f"⏩ Topic {data['title']} already in Silver DB. Skipping.")
            continue
            
        combined_transcript = ""
        for v in data['videos']:
            t = get_transcript(v['video_id'])
            if t: combined_transcript += f"\n{t}"
            
        if not combined_transcript:
            combined_transcript = f"Generate comprehensive notes for {data['title']}."

        ai_data = generate_ai_content(combined_transcript, data['title'])
        
        if ai_data:
            # 5. Extract Notes and Set Flags (1 or 0)
            raw_notes = ai_data.get('markdown_notes', "")
            quiz_data = json.dumps(ai_data.get('practice_test', []))
            
            notes_flag = 1 if raw_notes else 0
            qa_flag = 1 if ai_data.get('practice_test') else 0
            b64_notes = base64.b64encode(raw_notes.encode('utf-8')).decode('utf-8') if notes_flag else ""

            videos_json = json.dumps(data['videos'])
            
            silver_data.append((
                COURSE_ID, int(topic_id), data['title'], videos_json,
                notes_flag, qa_flag, b64_notes, quiz_data, current_time
            ))
            print(f"   ✅ Silver Data Ready! (Notes: {notes_flag}, QA: {qa_flag})")
            
        time.sleep(30) # Prevent API rate limits

    # 6. Save to Silver Table
    if silver_data:
        schema = StructType([
            StructField("course_id", StringType(), True),
            StructField("main_topic_id", IntegerType(), True),
            StructField("main_topic_name", StringType(), True),
            StructField("sub_videos_json", StringType(), True),
            StructField("notes_status", IntegerType(), True),
            StructField("qa_status", IntegerType(), True),
            StructField("notes_data", StringType(), True),
            StructField("qa_data", StringType(), True),
            StructField("updated_at", TimestampType(), True)
        ])
        df = spark.createDataFrame(silver_data, schema=schema)
        df.write.format("delta").mode("append").saveAsTable("courseify.default.course_silver")
        print("\n🎉 Job 2 Success! Data processed and saved to Silver Table.")
    else:
        print("\n✅ Silver Table is already up to date.")

if __name__ == "__main__":
    process_bronze_to_silver()
